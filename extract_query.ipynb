# %%
from transformers import AutoTokenizer
import json

model_path = "NousResearch/Hermes-2-Pro-Llama-3-8B"


tokenizer = AutoTokenizer.from_pretrained(model_path)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def get_best_candidate(obj):
    action = obj['action']
    try:
        if len(action):
            return action[0]
    except:
        return action

def get_func_obj_by_response(response):
    result = json.loads(response.replace("`", "").replace("\n", ""))
    func_obj = get_best_candidate(result)
    return func_obj

# %%
functions_description = """
Function: _list_data
    Description:
        Display some resumes in the system
    Params:

    Output:
        - List resumes


Function: _find_resume
    Description:
        - Search resumes by criteria: (GPA, major, skills, gender)
    Params:
        GPA
        - Description: GPA score at least
        - Type: float
        major
        - Description: Major of candidate
        - Type: String
        skills
        - Note: Skill is a name.
        - Description: Skill list of candidate
        gender
        - Type: Enum (male, female)
        job_title
        - Description: Past job titles, experience job
        - Type: List of string
    Output:
        - List resumes
        - If there is no information for a field, the value of that data field is not returned

"""

# %%
CONTROLLER_PROMPT_TEMPLATE = """You are a controller, you receive below query from user, utilize the insights and choose what is the best one main action from given functions

Query: $$QUERY$$

List function:
$$FUNCTIONS_DECRIPTION$$

The response should be exactly like format and don't say anything else:

```json
{
    "observation": <what is the current situation, what should follow>,
    "guidelines": <what is the most suitable action in this situation and why>,
    "action": {
        "fn": <function name 1>,
        "params": <function param 1>
    }
}
```
RESPONSE:
```json
"""

# %%
import ctranslate2

ct2_path = "./generative_model/llama_3_hermes"
generator = ctranslate2.Generator(
    ct2_path,
    device="cuda",
    compute_type = "int8_float16",
    device_index = [0],
    # flash_attention = True,
    inter_threads=4
)

from transformers import AutoTokenizer


model_path = "NousResearch/Hermes-2-Pro-Llama-3-8B"


tokenizer = AutoTokenizer.from_pretrained(model_path)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# query = "Find people has experiment in programming with linux or android"
# query = "Look for candidates with experience in AI and a degree in computer science. Male preferred"
# query = "Look for candidates with experience in AI and have a degree in computer science. Male preferred, priority is given to candidates who have worked in jobs related to data engineer and software engineer and GPA at least 3.8"

# %%
query = "Looking for candidates with experience in terms of AI and blockchain."
inputs = CONTROLLER_PROMPT_TEMPLATE.replace("$$QUERY$$", query).replace("$$FUNCTIONS_DECRIPTION$$", functions_description)
chat = [
    {
        "role": "user",
        "content": inputs
    }
]

prompt = tokenizer.apply_chat_template(chat, tokenize=False, add_generation_prompt=True)
prompts = [prompt]
token_inputs = [tokenizer.convert_ids_to_tokens(tokenizer.encode(prompt)) for prompt in prompts]


generated_text = generator.generate_batch(
    token_inputs,
    max_length=500,
    sampling_topp = 0.9,
    include_prompt_in_result=False,
    # end_token = [28789, 28749, 28767]
    # end_token = [28789, 28735, 28767]
    # end_token = [32005, 32006]
    # sampling_topk=10,
)
response = tokenizer.decode(generated_text[0].sequences_ids[0], skip_special_tokens=False)

print(response)
func_metadata = get_func_obj_by_response(response)
print(func_metadata)
# Out:
# {
#     "observation": "The user is looking for candidates with experience in AI and blockchain. We have resumes in the system that need to be filtered based on these criteria.",
#     "guidelines": "To find the most suitable candidates, we should search the resumes based on the given criteria of AI and blockchain experience.",
#     "action": {
#         "fn": "_find_resume",
#         "params": {
#             "skills": ["AI", "blockchain"]
#         }
#     }
# }
# ```
# {'fn': '_find_resume', 'params': {'skills': ['AI', 'blockchain']}}

# %%
import pymongo
import os
from dotenv import load_dotenv
load_dotenv(override=True)

connection_str = os.getenv("MONGODB_CONNECTION_STRING")
client = pymongo.MongoClient(connection_str)
database_name = os.getenv("CV_MONGO_DATABASE")
database = client[database_name]
collection = database["c_v_info"]

# %%
import re
float(re.findall("\d+\.\d+", "'gpa 3.85/4.00")[0])
# Out:
# 3.85

# %%
def check_gpa(gpa_str, gpa_min):
    try:
        gpa_str = "".join([c for c in gpa_str if c != "'"])
        gpa = float(re.findall("\d+\.\d+", gpa_str)[0])
        if gpa > gpa_min - 0.15:
            return 1
        return 0
    except:
        pass

# %%
import difflib
def check_major(arr, major):
    best_matches = difflib.get_close_matches(major, arr, n = 1, cutoff=0.3)
    if len(best_matches):
        return 1
    return 0

arr = [
    "advanced program",
    "ai/software research intern",
    "information and communication technology",
    "computer science"
    ]
# check_major(arr, major = "computer communication")

# %%
def check_skill(source_skills, target_skills):
    cnt = 0
    for skill in target_skills:

        # best_matches = difflib.get_close_matches(skill.lower(), source_skills, n = 1, cutoff=0.5)
        # if len(best_matches):
        #     return 1

        process_source_skills = []
        for source_skill in source_skills:
            s = ""
            for c in source_skill:
                if c.isalpha():
                    s += c
                else:
                    process_source_skills.append(s)
                    s = ""
            if s != "":
                process_source_skills.append(s)

        if skill.lower() in process_source_skills + source_skills:
            print(skill)
            cnt += 1

        if "and" in skill:
            sub_skills = skill.split("and")
            for sub_skill in sub_skills:
                if sub_skill.strip().lower() in process_source_skills + source_skills:
                    cnt += 1

    if (cnt == 0):
        return 0


    return cnt / len(target_skills)

# %%
def _find_resume(body):
    if 'gender' in body:
        data = list(collection.find({"gender": body['gender'].lower()}))
    else:
        data = list(collection.find({}))

    print(len(data))

    if 'GPA' in body:
        data = [item for item in data if check_gpa(item['gpa'], body['GPA'])]

    if 'major' in body:
        try:
            major = body['major'].lower()
        except:
            major = body['major'][0].lower()
        data = [item for item in data if check_major(item['major'], major)]

    print(len(data))

    total_skills = []
    if 'skills' in body:
        total_skills += [item.lower() for item in body['skills']]
    if 'job_title' in body:
        total_skills += [item.lower() for item in body['job_title']]

    if len(total_skills) == 0:
        names = []
        result = []
        for item in data:
            try:
                if item['name'][0] not in names:
                    names.append(item['name'][0])
                    result.append(item)
            except:
                names.append("anonymous")
        return [{**item, "score": 1} for item in data], names

    process_data = []

    for item in data:
        score = check_skill(item['skill'] + item['major'] + item['job_title'], total_skills)
        # if(score >= 0.8):
        process_data.append({**item, "score": score})



    data = process_data

    names = []
    result = []
    for item in data:
        try:
            if item['name'][0] not in names:
                names.append(item['name'][0])
                result.append(item)
        except:
            names.append("anonymous")

    return data, names
print(func_metadata['params'])
print(_find_resume(func_metadata['params']))
# Out:
# {'skills': ['AI', 'blockchain']}
# 11
# 11
# ai
# ai
# ai
# ai
# ai
# ai
# blockchain
# ([{'_id': ObjectId('66c6abfeea4dd50402925c8d'), 'organization': ['ho chi minh university of science', 'soict hackathon', 'vietai hanoi vietnam', 'foundation of deep learning and advanced natural language processing', 'tymlez cohort', 'naver samsung tiki and vietcombank', 'apcs', 'ieee international conference on systems man and cybernetics', 'ieee international conference on software testing verification and validation', 'katalon inc.', 'slu spoken language understanding', 'department of science and technology', 'ho chi minh university of science vietnam', 'advantech group', 'hanoi university of science and technology', 'benit ltd. hanoi vietnam', 'department of information and communications vietnam national university', 'ho chi minh vietnam', 'fodl', 'aiot innoworks', 'department of education and training hcm', 'bkai & naver'], 'major': ['ai/software research intern', 'advanced program', 'information and communication technology', 'computer science'], 'gpa': ['gpa 3.85/4.00'], 'name': ['thanh duy cao'], 'skill': ['flask', 'next.js', 'research', 'api testing', 'cvpr workshop', 'typescript', 'asr', 'reactjs', 'vctube', 'ai challenge', 'artificial intelligence', 'nestjs'], 'gender': ['male'], 'job_title': ['teaching assistant', 'developer intern'], 'profile_url': [], 'email': ['ctduy20@apcs.fitus.edu.vn'], 'phone': ['84 708 624 730'], 'education': ['bachelor'], 'batch_id': ObjectId('66c6abf7ea4dd50402925c8c'), 'file_path': '/data/files/cv/page/CaoThanhDuy_Resume.pdf', 'image_paths': ['/data/files/cv/image/CaoThanhDuy_Resume-0-1.png', '/data/files/cv/image/CaoThanhDuy_Resume-0-2.png', '/data/files/cv/image/CaoThanhDuy_Resume-1-1.png'], 'score': 0.5}, {'_id': ObjectId('66c6abfeea4dd50402925c8e'), 'organization': ['safehorizons', 'vietnam korea university of information and communication technology'], 'major': [], 'gpa': ['gpa 3.65'], 'name': ['nguyen thi chau thi'], 'skill': ['assisting students', 'java', 'mysql', 'css', 'firebase', 'inventory tracking', 'debugging', 'php', 'flutter', 'c++', 'restful', 'spring', 'html'], 'gender': ['female'], 'job_title': ['teaching assistant', 'software engineer', 'internship'], 'profile_url': [], 'email': ['chauthi1704@gmail.com'], 'phone': ['84387285692'], 'education': [], 'batch_id': ObjectId('66c6abf7ea4dd50402925c8c'), 'file_path': '/data/files/cv/page/ChauThi_resume.pdf', 'image_paths': [], 'score': 0}, {'_id': ObjectId('66c6abfeea4dd50402925c8f'), 'organization': ['tas design group', 'vng kms', 'dut danang vietnam', 'danang university of science and technology', 'youth union', 'university of science and technology organizational & volunteer'], 'major': [], 'gpa': ['gpa 3.89'], 'name': [], 'skill': ['raspberry pi', 'data analysis', 'eda', 'regression', 'teamwork', 'seaborn', 'c++', 'numpy', 'data processing', 'scikit', 'python', 'verbal communication', 'presentation', 'data visualization', 'ai model', 'matplotlib', 'communication', 'data driven', 'managing and administering the activities', 'forecasting', 'ml', 'machine learning', 'pytorch', 'english', 'artificial intelligence', 'scikit learn', 'data structures', 'neural networks', 'time series', 'data science', 'pandas', 'processing data', 'programming languages', 'dl', 'forecasting time series'], 'gender': [], 'job_title': ['deputy secretary'], 'profile_url': ['linkedin.com/in/quoc'], 'email': ['hoquocthienanh@gmail.com'], 'phone': ['0905500293'], 'education': ['bachelor'], 'batch_id': ObjectId('66c6abf7ea4dd50402925c8c'), 'file_path': '/data/files/cv/page/HoQuocThienAnh.pdf', 'image_paths': [], 'score': 0.5}, {'_id': ObjectId('66c6abfeea4dd50402925c90'), 'organization': ['github', 'nals joint stock company', 'vietnam bank for agriculture and rural development', 'hai chau da nang', 'da nang', 'vietnam korea university of ict', 'vietnam korea university of information and communication technology', 'vku excellent student', 'aglie', 'vku corporate scholarship'], 'major': ['computer science'], 'gpa': ['gpa 3.65'], 'name': ['huynh thi phuoc' ...

# %%
import gradio as gr
import time

# %%
CLASSIFIER_PROMPT_TEMPLATE ="""
You are a classifier, you receive the following query from the user and select which of the following type of query the user request falls into is given in json format with the following {key:value} format: (key is the action type, value is the meaning of the action):
{
"FIND": Command queries execute system functions: search for candidates who meet recruitment criteria, not summary function
"OTHERS": Other types of questions such as summary function, get resume example
}

"Note": If user only mention the above issues and ask questions about resume, the question type is still OTHERS

Query: $$QUERY$$


Please return a single string of the type of the query, not json. Do not return anything else.

RESPONSE: query_type

"""

# %%
# query = "Looking for candidates have experience with AI"
# query = "Give me summary information about CV has name: nguyen tien dung"
query = "Give me some resume example in your system"
inputs = CLASSIFIER_PROMPT_TEMPLATE.replace("$$QUERY$$", query)

chat = []
chat.append({
    "role": "user",
    "content": inputs
})

prompt = tokenizer.apply_chat_template(chat, tokenize=False, add_generation_prompt=True)
prompts = [prompt]
token_inputs = [tokenizer.convert_ids_to_tokens(tokenizer.encode(prompt)) for prompt in prompts]


generated_text = generator.generate_batch(
    token_inputs,
    max_length=500,
    sampling_topp = 0.9,
    include_prompt_in_result=False,
    # end_token = [28789, 28749, 28767]
    # end_token = [28789, 28735, 28767]
    # end_token = [32005, 32006]
    # sampling_topk=10,
)
response = tokenizer.decode(generated_text[0].sequences_ids[0], skip_special_tokens=False)
print(response)
# Out:
# OTHERS

# %%
conversation = None
def create_conversation(data):
    global conversation
    conversation = [
        {
            "role": "system",
            "content": f"You are a helpful assistant. When users ask about CV information, write it down in a summary way. Use below information to answer the question from user. \n Information: {str(data)}"
        }
    ]

# %%
init_data = list(collection.find())

# %%
MAX_THREAD = 10
examples = json.load(open('./data/examples.json', 'r'))


def slow_echo(message, history):
    query = message
    inputs = CLASSIFIER_PROMPT_TEMPLATE.replace("$$QUERY$$", query)

    chat = []
    chat.append({
        "role": "user",
        "content": inputs
    })

    prompt = tokenizer.apply_chat_template(chat, tokenize=False, add_generation_prompt=True)
    prompts = [prompt]
    token_inputs = [tokenizer.convert_ids_to_tokens(tokenizer.encode(prompt)) for prompt in prompts]


    generated_text = generator.generate_batch(
        token_inputs,
        max_length=500,
        sampling_topp = 0.9,
        include_prompt_in_result=False,
        # end_token = [28789, 28749, 28767]
        # end_token = [28789, 28735, 28767]
        # end_token = [32005, 32006]
        # sampling_topk=10,
    )
    response = tokenizer.decode(generated_text[0].sequences_ids[0], skip_special_tokens=False)

    response = response.replace("`", "").replace("\n", "")
    action_type = response

    if action_type == "FIND":


        inputs = CONTROLLER_PROMPT_TEMPLATE.replace("$$QUERY$$", query).replace("$$FUNCTIONS_DECRIPTION$$", functions_description)

        chat = [
            {
                "role": "system",
                "content": f"Use information in detailed resume data to answer the question from user."
            }
        ]


        chat.append({
            "role": "user",
            "content": inputs
        })

        prompt = tokenizer.apply_chat_template(chat, tokenize=False, add_generation_prompt=True)
        prompts = [prompt]
        token_inputs = [tokenizer.convert_ids_to_tokens(tokenizer.encode(prompt)) for prompt in prompts]


        generated_text = generator.generate_batch(
            token_inputs,
            max_length=500,
            sampling_topp = 0.9,
            include_prompt_in_result=False,
            # end_token = [28789, 28749, 28767]
            # end_token = [28789, 28735, 28767]
            # end_token = [32005, 32006]
            # sampling_topk=10,
        )
        response = tokenizer.decode(generated_text[0].sequences_ids[0], skip_special_tokens=False)

        func_metadata = get_func_obj_by_response(response)
        print(func_metadata['params'])
        result, names = _find_resume(func_metadata['params'])
        print(result)
        response = ""

        all_datas = []
        cnt = 1
        for i, item in enumerate(result):
            if item['score']:
                response += f"{cnt}. ***Name:*** {names[i]} - ***Score:*** {item['score']}\n+ ***Link:*** http://localhost:8001{item['file_path']}\n\n"
                del item['score']
                del item['batch_id']
                del item['image_paths']
                all_datas.append(item)
                cnt += 1

        for i in range(len(response)):
            time.sleep(0.01)
            yield "Here are best resume matches:\n " + response[: i+1]

        create_conversation(all_datas)
        # chat.append({
        #     "role": "assistant",
        #     "content": response + f"\n Detailed resume data: {str(all_datas)}"
        # })
    else:

        if conversation is None:
            tmp = []
            for i, item in enumerate(init_data):
                del item['batch_id']
                del item['image_paths']
                tmp.append(item)
            create_conversation(tmp)
        conversation.append({
            "role": "user",
            "content": query
        })

        print(conversation)

        prompt = tokenizer.apply_chat_template(conversation, tokenize=False, add_generation_prompt=True)
        prompts = [prompt]
        token_inputs = [tokenizer.convert_ids_to_tokens(tokenizer.encode(prompt)) for prompt in prompts]


        generated_text = generator.generate_batch(
            token_inputs,
            max_length=500,
            sampling_topp = 0.9,
            include_prompt_in_result=False,
            # end_token = [28789, 28749, 28767]
            # end_token = [28789, 28735, 28767]
            # end_token = [32005, 32006]
            # sampling_topk=10,
        )
        response = tokenizer.decode(generated_text[0].sequences_ids[0], skip_special_tokens=False)

        yield response



gr.ChatInterface(slow_echo, title = "Resume Search Summer Soict 2024", examples = examples).launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://f13b6ccd788b93f7a1.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f13b6ccd788b93f7a1.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# {'skills': ['AI', 'deep learning', 'machine learning']}
# 11
# 11
# ai
# ai
# machine learning
# ai
# machine learning
# ai
# deep learning
# machine learning
# ai
# deep learning
# machine learning
# deep learning
# machine learning
# ai
# deep learning
# [{'_id': ObjectId('66c6abfeea4dd50402925c8d'), 'organization': ['ho chi minh university of science', 'soict hackathon', 'vietai hanoi vietnam', 'foundation of deep learning and advanced natural language processing', 'tymlez cohort', 'naver samsung tiki and vietcombank', 'apcs', 'ieee international conference on systems man and cybernetics', 'ieee international conference on software testing verification and validation', 'katalon inc.', 'slu spoken language understanding', 'department of science and technology', 'ho chi minh university of science vietnam', 'advantech group', 'hanoi university of science and technology', 'benit ltd. hanoi vietnam', 'department of information and communications vietnam national university', 'ho chi minh vietnam', 'fodl', 'aiot innoworks', 'department of education and training hcm', 'bkai & naver'], 'major': ['ai/software research intern', 'advanced program', 'information and communication technology', 'computer science'], 'gpa': ['gpa 3.85/4.00'], 'name': ['thanh duy cao'], 'skill': ['flask', 'next.js', 'research', 'api testing', 'cvpr workshop', 'typescript', 'asr', 'reactjs', 'vctube', 'ai challenge', 'artificial intelligence', 'nestjs'], 'gender': ['male'], 'job_title': ['teaching assistant', 'developer intern'], 'profile_url': [], 'email': ['ctduy20@apcs.fitus.edu.vn'], 'phone': ['84 708 624 730'], 'education': ['bachelor'], 'batch_id': ObjectId('66c6abf7ea4dd50402925c8c'), 'file_path': '/data/files/cv/page/CaoThanhDuy_Resume.pdf', 'image_paths': ['/data/files/cv/image/CaoThanhDuy_Resume-0-1.png', '/data/files/cv/image/CaoThanhDuy_Resume-0-2.png', '/data/files/cv/image/CaoThanhDuy_Resume-1-1.png'], 'score': 0.3333333333333333}, {'_id': ObjectId('66c6abfeea4dd50402925c8e'), 'organization': ['safehorizons', 'vietnam korea university of information and communication technology'], 'major': [], 'gpa': ['gpa 3.65'], 'name': ['nguyen thi chau thi'], 'skill': ['assisting students', 'java', 'mysql', 'css', 'firebase', 'inventory tracking', 'debugging', 'php', 'flutter', 'c++', 'restful', 'spring', 'html'], 'gender': ['female'], 'job_title': ['teaching assistant', 'software engineer', 'internship'], 'profile_url': [], 'email': ['chauthi1704@gmail.com'], 'phone': ['84387285692'], 'education': [], 'batch_id': ObjectId('66c6abf7ea4dd50402925c8c'), 'file_path': '/data/files/cv/page/ChauThi_resume.pdf', 'image_paths': [], 'score': 0}, {'_id': ObjectId('66c6abfeea4dd50402925c8f'), 'organization': ['tas design group', 'vng kms', 'dut danang vietnam', 'danang university of science and technology', 'youth union', 'university of science and technology organizational & volunteer'], 'major': [], 'gpa': ['gpa 3.89'], 'name': [], 'skill': ['raspberry pi', 'data analysis', 'eda', 'regression', 'teamwork', 'seaborn', 'c++', 'numpy', 'data processing', 'scikit', 'python', 'verbal communication', 'presentation', 'data visualization', 'ai model', 'matplotlib', 'communication', 'data driven', 'managing and administering the activities', 'forecasting', 'ml', 'machine learning', 'pytorch', 'english', 'artificial intelligence', 'scikit learn', 'data structures', 'neural networks', 'time series', 'data science', 'pandas', 'processing data', 'programming languages', 'dl', 'forecasting time series'], 'gender': [], 'job_title': ['deputy secretary'], 'profile_url': ['linkedin.com/in/quoc'], 'email': ['hoquocthienanh@gmail.com'], 'phone': ['0905500293'], 'education': ['bachelor'], 'batch_id': ObjectId('66c6abf7ea4dd50402925c8c'), 'file_path': '/data/files/cv/page/HoQuocThienAnh.pdf', 'image_paths': [], 'score': 0.6666666666666666}, {'_id': ObjectId('66c6abfeea4dd50402925c90'), 'organization': ['github', 'nals joint stock company', 'vietnam bank for agriculture and rural development', 'hai chau da nang', 'da nang', 'vietnam korea university of ict', 'vietnam korea university of information and communication technology', 'vku excellent student', 'aglie', 'vku corporate scholarship'], 'major': ['computer science'], 'gpa': ['gpa 3.65' ...
# [{'role': 'system', 'content': 'You are a helpful assistant. When users ask about CV information, write it down in a summary way. Use below information to answer the question from user. \n Information: [{\'_id\': ObjectId(\'66c6abfeea4dd50402925c8d\'), \'organization\': [\'ho chi minh university of science\', \'soict hackathon\', \'vietai hanoi vietnam\', \'foundation of deep learning and advanced natural language processing\', \'tymlez cohort\', \'naver samsung tiki and vietcombank\', \'apcs\', \'ieee international conference on systems man and cybernetics\', \'ieee international conference on software testing verification and validation\', \'katalon inc.\', \'slu spoken language understanding\', \'department of science and technology\', \'ho chi minh university of science vietnam\', \'advantech group\', \'hanoi university of science and technology\', \'benit ltd. hanoi vietnam\', \'department of information and communications vietnam national university\', \'ho chi minh vietnam\', \'fodl\', \'aiot innoworks\', \'department of education and training hcm\', \'bkai & naver\'], \'major\': [\'ai/software research intern\', \'advanced program\', \'information and communication technology\', \'computer science\'], \'gpa\': [\'gpa 3.85/4.00\'], \'name\': [\'thanh duy cao\'], \'skill\': [\'flask\', \'next.js\', \'research\', \'api testing\', \'cvpr workshop\', \'typescript\', \'asr\', \'reactjs\', \'vctube\', \'ai challenge\', \'artificial intelligence\', \'nestjs\'], \'gender\': [\'male\'], \'job_title\': [\'teaching assistant\', \'developer intern\'], \'profile_url\': [], \'email\': [\'ctduy20@apcs.fitus.edu.vn\'], \'phone\': [\'84 708 624 730\'], \'education\': [\'bachelor\'], \'file_path\': \'/data/files/cv/page/CaoThanhDuy_Resume.pdf\'}, {\'_id\': ObjectId(\'66c6abfeea4dd50402925c8f\'), \'organization\': [\'tas design group\', \'vng kms\', \'dut danang vietnam\', \'danang university of science and technology\', \'youth union\', \'university of science and technology organizational & volunteer\'], \'major\': [], \'gpa\': [\'gpa 3.89\'], \'name\': [], \'skill\': [\'raspberry pi\', \'data analysis\', \'eda\', \'regression\', \'teamwork\', \'seaborn\', \'c++\', \'numpy\', \'data processing\', \'scikit\', \'python\', \'verbal communication\', \'presentation\', \'data visualization\', \'ai model\', \'matplotlib\', \'communication\', \'data driven\', \'managing and administering the activities\', \'forecasting\', \'ml\', \'machine learning\', \'pytorch\', \'english\', \'artificial intelligence\', \'scikit learn\', \'data structures\', \'neural networks\', \'time series\', \'data science\', \'pandas\', \'processing data\', \'programming languages\', \'dl\', \'forecasting time series\'], \'gender\': [], \'job_title\': [\'deputy secretary\'], \'profile_url\': [\'linkedin.com/in/quoc\'], \'email\': [\'hoquocthienanh@gmail.com\'], \'phone\': [\'0905500293\'], \'education\': [\'bachelor\'], \'file_path\': \'/data/files/cv/page/HoQuocThienAnh.pdf\'}, {\'_id\': ObjectId(\'66c6abfeea4dd50402925c91\'), \'organization\': [\'pixta vietnam company\', \'ha noi teacher\', \'ha noi university of science and technology\', \'ha noi research assistant\', \'ha noi labeling data\', \'hanoi university of science and technology\', \'hust semester\', \'bkai international research center\', \'school of information and communication technology\'], \'major\': [\'computer science\'], \'gpa\': [\'3.72/4 achievements\'], \'name\': [\'nguyen hoang phuc\'], \'skill\': [\'imdb\', \'data analytics\', \'css\', \'c++\', \'mongodb\', \'python\', \'image classification\', \'mysql\', \'c\', \'pycharm\', \'project management\', \'tensorflow\', \'java\', \'rag\', \'deverloper\', \'pytorch\', \'intellij\', \'cpa\', \'html\', \'visual studio code\', \'idea\', \'data science\', \'chatbot\', \'javascript\', \'object oriented\', \'cloud/databases\'], \'gender\': [\'male\'], \'job_title\': [\'teacher assistant\', \'ai engineer\'], \'profile_url\': [], \'email\': [\'phuc.nh215452@si ...
# [{'role': 'system', 'content': 'You are a helpful assistant. When users ask about CV information, write it down in a summary way. Use below information to answer the question from user. \n Information: [{\'_id\': ObjectId(\'66c6abfeea4dd50402925c8d\'), \'organization\': [\'ho chi minh university of science\', \'soict hackathon\', \'vietai hanoi vietnam\', \'foundation of deep learning and advanced natural language processing\', \'tymlez cohort\', \'naver samsung tiki and vietcombank\', \'apcs\', \'ieee international conference on systems man and cybernetics\', \'ieee international conference on software testing verification and validation\', \'katalon inc.\', \'slu spoken language understanding\', \'department of science and technology\', \'ho chi minh university of science vietnam\', \'advantech group\', \'hanoi university of science and technology\', \'benit ltd. hanoi vietnam\', \'department of information and communications vietnam national university\', \'ho chi minh vietnam\', \'fodl\', \'aiot innoworks\', \'department of education and training hcm\', \'bkai & naver\'], \'major\': [\'ai/software research intern\', \'advanced program\', \'information and communication technology\', \'computer science\'], \'gpa\': [\'gpa 3.85/4.00\'], \'name\': [\'thanh duy cao\'], \'skill\': [\'flask\', \'next.js\', \'research\', \'api testing\', \'cvpr workshop\', \'typescript\', \'asr\', \'reactjs\', \'vctube\', \'ai challenge\', \'artificial intelligence\', \'nestjs\'], \'gender\': [\'male\'], \'job_title\': [\'teaching assistant\', \'developer intern\'], \'profile_url\': [], \'email\': [\'ctduy20@apcs.fitus.edu.vn\'], \'phone\': [\'84 708 624 730\'], \'education\': [\'bachelor\'], \'file_path\': \'/data/files/cv/page/CaoThanhDuy_Resume.pdf\'}, {\'_id\': ObjectId(\'66c6abfeea4dd50402925c8f\'), \'organization\': [\'tas design group\', \'vng kms\', \'dut danang vietnam\', \'danang university of science and technology\', \'youth union\', \'university of science and technology organizational & volunteer\'], \'major\': [], \'gpa\': [\'gpa 3.89\'], \'name\': [], \'skill\': [\'raspberry pi\', \'data analysis\', \'eda\', \'regression\', \'teamwork\', \'seaborn\', \'c++\', \'numpy\', \'data processing\', \'scikit\', \'python\', \'verbal communication\', \'presentation\', \'data visualization\', \'ai model\', \'matplotlib\', \'communication\', \'data driven\', \'managing and administering the activities\', \'forecasting\', \'ml\', \'machine learning\', \'pytorch\', \'english\', \'artificial intelligence\', \'scikit learn\', \'data structures\', \'neural networks\', \'time series\', \'data science\', \'pandas\', \'processing data\', \'programming languages\', \'dl\', \'forecasting time series\'], \'gender\': [], \'job_title\': [\'deputy secretary\'], \'profile_url\': [\'linkedin.com/in/quoc\'], \'email\': [\'hoquocthienanh@gmail.com\'], \'phone\': [\'0905500293\'], \'education\': [\'bachelor\'], \'file_path\': \'/data/files/cv/page/HoQuocThienAnh.pdf\'}, {\'_id\': ObjectId(\'66c6abfeea4dd50402925c91\'), \'organization\': [\'pixta vietnam company\', \'ha noi teacher\', \'ha noi university of science and technology\', \'ha noi research assistant\', \'ha noi labeling data\', \'hanoi university of science and technology\', \'hust semester\', \'bkai international research center\', \'school of information and communication technology\'], \'major\': [\'computer science\'], \'gpa\': [\'3.72/4 achievements\'], \'name\': [\'nguyen hoang phuc\'], \'skill\': [\'imdb\', \'data analytics\', \'css\', \'c++\', \'mongodb\', \'python\', \'image classification\', \'mysql\', \'c\', \'pycharm\', \'project management\', \'tensorflow\', \'java\', \'rag\', \'deverloper\', \'pytorch\', \'intellij\', \'cpa\', \'html\', \'visual studio code\', \'idea\', \'data science\', \'chatbot\', \'javascript\', \'object oriented\', \'cloud/databases\'], \'gender\': [\'male\'], \'job_title\': [\'teacher assistant\', \'ai engineer\'], \'profile_url\': [], \'email\': [\'phuc.nh215452@si ...
# [{'role': 'system', 'content': 'You are a helpful assistant. When users ask about CV information, write it down in a summary way. Use below information to answer the question from user. \n Information: [{\'_id\': ObjectId(\'66c6abfeea4dd50402925c8d\'), \'organization\': [\'ho chi minh university of science\', \'soict hackathon\', \'vietai hanoi vietnam\', \'foundation of deep learning and advanced natural language processing\', \'tymlez cohort\', \'naver samsung tiki and vietcombank\', \'apcs\', \'ieee international conference on systems man and cybernetics\', \'ieee international conference on software testing verification and validation\', \'katalon inc.\', \'slu spoken language understanding\', \'department of science and technology\', \'ho chi minh university of science vietnam\', \'advantech group\', \'hanoi university of science and technology\', \'benit ltd. hanoi vietnam\', \'department of information and communications vietnam national university\', \'ho chi minh vietnam\', \'fodl\', \'aiot innoworks\', \'department of education and training hcm\', \'bkai & naver\'], \'major\': [\'ai/software research intern\', \'advanced program\', \'information and communication technology\', \'computer science\'], \'gpa\': [\'gpa 3.85/4.00\'], \'name\': [\'thanh duy cao\'], \'skill\': [\'flask\', \'next.js\', \'research\', \'api testing\', \'cvpr workshop\', \'typescript\', \'asr\', \'reactjs\', \'vctube\', \'ai challenge\', \'artificial intelligence\', \'nestjs\'], \'gender\': [\'male\'], \'job_title\': [\'teaching assistant\', \'developer intern\'], \'profile_url\': [], \'email\': [\'ctduy20@apcs.fitus.edu.vn\'], \'phone\': [\'84 708 624 730\'], \'education\': [\'bachelor\'], \'file_path\': \'/data/files/cv/page/CaoThanhDuy_Resume.pdf\'}, {\'_id\': ObjectId(\'66c6abfeea4dd50402925c8f\'), \'organization\': [\'tas design group\', \'vng kms\', \'dut danang vietnam\', \'danang university of science and technology\', \'youth union\', \'university of science and technology organizational & volunteer\'], \'major\': [], \'gpa\': [\'gpa 3.89\'], \'name\': [], \'skill\': [\'raspberry pi\', \'data analysis\', \'eda\', \'regression\', \'teamwork\', \'seaborn\', \'c++\', \'numpy\', \'data processing\', \'scikit\', \'python\', \'verbal communication\', \'presentation\', \'data visualization\', \'ai model\', \'matplotlib\', \'communication\', \'data driven\', \'managing and administering the activities\', \'forecasting\', \'ml\', \'machine learning\', \'pytorch\', \'english\', \'artificial intelligence\', \'scikit learn\', \'data structures\', \'neural networks\', \'time series\', \'data science\', \'pandas\', \'processing data\', \'programming languages\', \'dl\', \'forecasting time series\'], \'gender\': [], \'job_title\': [\'deputy secretary\'], \'profile_url\': [\'linkedin.com/in/quoc\'], \'email\': [\'hoquocthienanh@gmail.com\'], \'phone\': [\'0905500293\'], \'education\': [\'bachelor\'], \'file_path\': \'/data/files/cv/page/HoQuocThienAnh.pdf\'}, {\'_id\': ObjectId(\'66c6abfeea4dd50402925c91\'), \'organization\': [\'pixta vietnam company\', \'ha noi teacher\', \'ha noi university of science and technology\', \'ha noi research assistant\', \'ha noi labeling data\', \'hanoi university of science and technology\', \'hust semester\', \'bkai international research center\', \'school of information and communication technology\'], \'major\': [\'computer science\'], \'gpa\': [\'3.72/4 achievements\'], \'name\': [\'nguyen hoang phuc\'], \'skill\': [\'imdb\', \'data analytics\', \'css\', \'c++\', \'mongodb\', \'python\', \'image classification\', \'mysql\', \'c\', \'pycharm\', \'project management\', \'tensorflow\', \'java\', \'rag\', \'deverloper\', \'pytorch\', \'intellij\', \'cpa\', \'html\', \'visual studio code\', \'idea\', \'data science\', \'chatbot\', \'javascript\', \'object oriented\', \'cloud/databases\'], \'gender\': [\'male\'], \'job_title\': [\'teacher assistant\', \'ai engineer\'], \'profile_url\': [], \'email\': [\'phuc.nh215452@si ...
# [{'role': 'system', 'content': 'You are a helpful assistant. When users ask about CV information, write it down in a summary way. Use below information to answer the question from user. \n Information: [{\'_id\': ObjectId(\'66c6abfeea4dd50402925c8d\'), \'organization\': [\'ho chi minh university of science\', \'soict hackathon\', \'vietai hanoi vietnam\', \'foundation of deep learning and advanced natural language processing\', \'tymlez cohort\', \'naver samsung tiki and vietcombank\', \'apcs\', \'ieee international conference on systems man and cybernetics\', \'ieee international conference on software testing verification and validation\', \'katalon inc.\', \'slu spoken language understanding\', \'department of science and technology\', \'ho chi minh university of science vietnam\', \'advantech group\', \'hanoi university of science and technology\', \'benit ltd. hanoi vietnam\', \'department of information and communications vietnam national university\', \'ho chi minh vietnam\', \'fodl\', \'aiot innoworks\', \'department of education and training hcm\', \'bkai & naver\'], \'major\': [\'ai/software research intern\', \'advanced program\', \'information and communication technology\', \'computer science\'], \'gpa\': [\'gpa 3.85/4.00\'], \'name\': [\'thanh duy cao\'], \'skill\': [\'flask\', \'next.js\', \'research\', \'api testing\', \'cvpr workshop\', \'typescript\', \'asr\', \'reactjs\', \'vctube\', \'ai challenge\', \'artificial intelligence\', \'nestjs\'], \'gender\': [\'male\'], \'job_title\': [\'teaching assistant\', \'developer intern\'], \'profile_url\': [], \'email\': [\'ctduy20@apcs.fitus.edu.vn\'], \'phone\': [\'84 708 624 730\'], \'education\': [\'bachelor\'], \'file_path\': \'/data/files/cv/page/CaoThanhDuy_Resume.pdf\'}, {\'_id\': ObjectId(\'66c6abfeea4dd50402925c8f\'), \'organization\': [\'tas design group\', \'vng kms\', \'dut danang vietnam\', \'danang university of science and technology\', \'youth union\', \'university of science and technology organizational & volunteer\'], \'major\': [], \'gpa\': [\'gpa 3.89\'], \'name\': [], \'skill\': [\'raspberry pi\', \'data analysis\', \'eda\', \'regression\', \'teamwork\', \'seaborn\', \'c++\', \'numpy\', \'data processing\', \'scikit\', \'python\', \'verbal communication\', \'presentation\', \'data visualization\', \'ai model\', \'matplotlib\', \'communication\', \'data driven\', \'managing and administering the activities\', \'forecasting\', \'ml\', \'machine learning\', \'pytorch\', \'english\', \'artificial intelligence\', \'scikit learn\', \'data structures\', \'neural networks\', \'time series\', \'data science\', \'pandas\', \'processing data\', \'programming languages\', \'dl\', \'forecasting time series\'], \'gender\': [], \'job_title\': [\'deputy secretary\'], \'profile_url\': [\'linkedin.com/in/quoc\'], \'email\': [\'hoquocthienanh@gmail.com\'], \'phone\': [\'0905500293\'], \'education\': [\'bachelor\'], \'file_path\': \'/data/files/cv/page/HoQuocThienAnh.pdf\'}, {\'_id\': ObjectId(\'66c6abfeea4dd50402925c91\'), \'organization\': [\'pixta vietnam company\', \'ha noi teacher\', \'ha noi university of science and technology\', \'ha noi research assistant\', \'ha noi labeling data\', \'hanoi university of science and technology\', \'hust semester\', \'bkai international research center\', \'school of information and communication technology\'], \'major\': [\'computer science\'], \'gpa\': [\'3.72/4 achievements\'], \'name\': [\'nguyen hoang phuc\'], \'skill\': [\'imdb\', \'data analytics\', \'css\', \'c++\', \'mongodb\', \'python\', \'image classification\', \'mysql\', \'c\', \'pycharm\', \'project management\', \'tensorflow\', \'java\', \'rag\', \'deverloper\', \'pytorch\', \'intellij\', \'cpa\', \'html\', \'visual studio code\', \'idea\', \'data science\', \'chatbot\', \'javascript\', \'object oriented\', \'cloud/databases\'], \'gender\': [\'male\'], \'job_title\': [\'teacher assistant\', \'ai engineer\'], \'profile_url\': [], \'email\': [\'phuc.nh215452@si ...
# {'skills': ['deep learning', 'machine learning']}
# 11
# 11
# machine learning
# machine learning
# deep learning
# machine learning
# deep learning
# machine learning
# deep learning
# machine learning
# deep learning
# [{'_id': ObjectId('66c6abfeea4dd50402925c8d'), 'organization': ['ho chi minh university of science', 'soict hackathon', 'vietai hanoi vietnam', 'foundation of deep learning and advanced natural language processing', 'tymlez cohort', 'naver samsung tiki and vietcombank', 'apcs', 'ieee international conference on systems man and cybernetics', 'ieee international conference on software testing verification and validation', 'katalon inc.', 'slu spoken language understanding', 'department of science and technology', 'ho chi minh university of science vietnam', 'advantech group', 'hanoi university of science and technology', 'benit ltd. hanoi vietnam', 'department of information and communications vietnam national university', 'ho chi minh vietnam', 'fodl', 'aiot innoworks', 'department of education and training hcm', 'bkai & naver'], 'major': ['ai/software research intern', 'advanced program', 'information and communication technology', 'computer science'], 'gpa': ['gpa 3.85/4.00'], 'name': ['thanh duy cao'], 'skill': ['flask', 'next.js', 'research', 'api testing', 'cvpr workshop', 'typescript', 'asr', 'reactjs', 'vctube', 'ai challenge', 'artificial intelligence', 'nestjs'], 'gender': ['male'], 'job_title': ['teaching assistant', 'developer intern'], 'profile_url': [], 'email': ['ctduy20@apcs.fitus.edu.vn'], 'phone': ['84 708 624 730'], 'education': ['bachelor'], 'batch_id': ObjectId('66c6abf7ea4dd50402925c8c'), 'file_path': '/data/files/cv/page/CaoThanhDuy_Resume.pdf', 'image_paths': ['/data/files/cv/image/CaoThanhDuy_Resume-0-1.png', '/data/files/cv/image/CaoThanhDuy_Resume-0-2.png', '/data/files/cv/image/CaoThanhDuy_Resume-1-1.png'], 'score': 0}, {'_id': ObjectId('66c6abfeea4dd50402925c8e'), 'organization': ['safehorizons', 'vietnam korea university of information and communication technology'], 'major': [], 'gpa': ['gpa 3.65'], 'name': ['nguyen thi chau thi'], 'skill': ['assisting students', 'java', 'mysql', 'css', 'firebase', 'inventory tracking', 'debugging', 'php', 'flutter', 'c++', 'restful', 'spring', 'html'], 'gender': ['female'], 'job_title': ['teaching assistant', 'software engineer', 'internship'], 'profile_url': [], 'email': ['chauthi1704@gmail.com'], 'phone': ['84387285692'], 'education': [], 'batch_id': ObjectId('66c6abf7ea4dd50402925c8c'), 'file_path': '/data/files/cv/page/ChauThi_resume.pdf', 'image_paths': [], 'score': 0}, {'_id': ObjectId('66c6abfeea4dd50402925c8f'), 'organization': ['tas design group', 'vng kms', 'dut danang vietnam', 'danang university of science and technology', 'youth union', 'university of science and technology organizational & volunteer'], 'major': [], 'gpa': ['gpa 3.89'], 'name': [], 'skill': ['raspberry pi', 'data analysis', 'eda', 'regression', 'teamwork', 'seaborn', 'c++', 'numpy', 'data processing', 'scikit', 'python', 'verbal communication', 'presentation', 'data visualization', 'ai model', 'matplotlib', 'communication', 'data driven', 'managing and administering the activities', 'forecasting', 'ml', 'machine learning', 'pytorch', 'english', 'artificial intelligence', 'scikit learn', 'data structures', 'neural networks', 'time series', 'data science', 'pandas', 'processing data', 'programming languages', 'dl', 'forecasting time series'], 'gender': [], 'job_title': ['deputy secretary'], 'profile_url': ['linkedin.com/in/quoc'], 'email': ['hoquocthienanh@gmail.com'], 'phone': ['0905500293'], 'education': ['bachelor'], 'batch_id': ObjectId('66c6abf7ea4dd50402925c8c'), 'file_path': '/data/files/cv/page/HoQuocThienAnh.pdf', 'image_paths': [], 'score': 0.5}, {'_id': ObjectId('66c6abfeea4dd50402925c90'), 'organization': ['github', 'nals joint stock company', 'vietnam bank for agriculture and rural development', 'hai chau da nang', 'da nang', 'vietnam korea university of ict', 'vietnam korea university of information and communication technology', 'vku excellent student', 'aglie', 'vku corporate scholarship'], 'major': ['computer science'], 'gpa': ['gpa 3.65'], 'name': ['huynh thi phuoc'],  ...
# [{'role': 'system', 'content': 'You are a helpful assistant. When users ask about CV information, write it down in a summary way. Use below information to answer the question from user. \n Information: [{\'_id\': ObjectId(\'66c6abfeea4dd50402925c8f\'), \'organization\': [\'tas design group\', \'vng kms\', \'dut danang vietnam\', \'danang university of science and technology\', \'youth union\', \'university of science and technology organizational & volunteer\'], \'major\': [], \'gpa\': [\'gpa 3.89\'], \'name\': [], \'skill\': [\'raspberry pi\', \'data analysis\', \'eda\', \'regression\', \'teamwork\', \'seaborn\', \'c++\', \'numpy\', \'data processing\', \'scikit\', \'python\', \'verbal communication\', \'presentation\', \'data visualization\', \'ai model\', \'matplotlib\', \'communication\', \'data driven\', \'managing and administering the activities\', \'forecasting\', \'ml\', \'machine learning\', \'pytorch\', \'english\', \'artificial intelligence\', \'scikit learn\', \'data structures\', \'neural networks\', \'time series\', \'data science\', \'pandas\', \'processing data\', \'programming languages\', \'dl\', \'forecasting time series\'], \'gender\': [], \'job_title\': [\'deputy secretary\'], \'profile_url\': [\'linkedin.com/in/quoc\'], \'email\': [\'hoquocthienanh@gmail.com\'], \'phone\': [\'0905500293\'], \'education\': [\'bachelor\'], \'file_path\': \'/data/files/cv/page/HoQuocThienAnh.pdf\'}, {\'_id\': ObjectId(\'66c6abfeea4dd50402925c92\'), \'organization\': [\'school of electronics & telecommunications\', \'samsung\', \'r&d\', \'srv\', \'hanoi university of science & technology\'], \'major\': [\'computer engineering\'], \'gpa\': [], \'name\': [\'nguyen tien dung\'], \'skill\': [\'windows os\', \'ejabberd\', \'docker\', \'c/c++\', \'ipv6\', \'pipeline\', \'os\', \'tizen\', \'python\', \'webrtc\', \'smack\', \'cicd\', \'agile\', \'ubuntu os\', \'windows\', \'linux\', \'testing\', \'java\', \'migrate\', \'ops\', \'ml\', \'machine learning\', \'embbeded\', \'flutter\', \'deploying and monitoring\', \'opearting\', \'identify observations events\', \'git\', \'systemd\', \'unix\', \'xmpp\', \'team working\', \'jira\', \'ios\', \'android\', \'dart\'], \'gender\': [\'male\'], \'job_title\': [\'software engineer\', \'developer\'], \'profile_url\': [\'mail.com\', \'www.terabit.com.au/\', \'www.ejabberd.im/\', \'topcv.vn\'], \'email\': [], \'phone\': [\'0973621049\'], \'education\': [], \'file_path\': \'/data/files/cv/page/Nguyen-Tien-Dung.pdf\'}, {\'_id\': ObjectId(\'66c6abfeea4dd50402925c93\'), \'organization\': [\'fschool\', \'hanoi university of science and technology\', \'ftech.ai\', \'the school of information and communications technology hanoi university\', \'sekisho sponsored japanese language scholarship\'], \'major\': [\'mathematics and informatics\'], \'gpa\': [], \'name\': [\'nguyen van nghiem\'], \'skill\': [\'seallms\', \'object oriented programming\', \'bm25\', \'llms\', \'problem solving\', \'oop\', \'large language\', \'/\', \'docker\', \'c/c++\', \'vllm\', \'python\', \'vinallama\', \'database\', \'llm\', \'math\', \'github\', \'tensorflow\', \'deep learning\', \'rtx\', \'vectordb\', \'rag\', \'chromadb\', \'jd\', \'mathematics\', \'machine learning\', \'pytorch\', \'cpa\', \'git\', \'gpt\', \'c#\', \'chatbot\', \'hackathon\', \'ftech.ai\', \'sql server\'], \'gender\': [\'male\'], \'job_title\': [\'teaching assistant\', \'nlp engineer\', \'ai engineer\'], \'profile_url\': [\'github.com/nguyenvannghiem0312/SAMI_Q\', \'github.com/nguyenvannghiem0312\', \'FQA.vn\', \'topcv.vn\', \'FTECH.AI\', \'github.com/nguyenvannghiem0312/AI_CHALLENGE\', \'github.com/nguyenvannghiem0312/Recommendation_system_for_recruitment\'], \'email\': [\'nguyenvannghiem0312@gmail.com\'], \'phone\': [\'0399802905\'], \'education\': [\'bachelor\'], \'file_path\': \'/data/files/cv/page/NguyenVanNghiem.pdf\'}, {\'_id\': ObjectId(\'66c6abfeea4dd50402925c95\'), \'organization\': [\'tu quang & dat pham & can\', \'phenikaa university\', \'univer ...
# [{'role': 'system', 'content': 'You are a helpful assistant. When users ask about CV information, write it down in a summary way. Use below information to answer the question from user. \n Information: [{\'_id\': ObjectId(\'66c6abfeea4dd50402925c8f\'), \'organization\': [\'tas design group\', \'vng kms\', \'dut danang vietnam\', \'danang university of science and technology\', \'youth union\', \'university of science and technology organizational & volunteer\'], \'major\': [], \'gpa\': [\'gpa 3.89\'], \'name\': [], \'skill\': [\'raspberry pi\', \'data analysis\', \'eda\', \'regression\', \'teamwork\', \'seaborn\', \'c++\', \'numpy\', \'data processing\', \'scikit\', \'python\', \'verbal communication\', \'presentation\', \'data visualization\', \'ai model\', \'matplotlib\', \'communication\', \'data driven\', \'managing and administering the activities\', \'forecasting\', \'ml\', \'machine learning\', \'pytorch\', \'english\', \'artificial intelligence\', \'scikit learn\', \'data structures\', \'neural networks\', \'time series\', \'data science\', \'pandas\', \'processing data\', \'programming languages\', \'dl\', \'forecasting time series\'], \'gender\': [], \'job_title\': [\'deputy secretary\'], \'profile_url\': [\'linkedin.com/in/quoc\'], \'email\': [\'hoquocthienanh@gmail.com\'], \'phone\': [\'0905500293\'], \'education\': [\'bachelor\'], \'file_path\': \'/data/files/cv/page/HoQuocThienAnh.pdf\'}, {\'_id\': ObjectId(\'66c6abfeea4dd50402925c92\'), \'organization\': [\'school of electronics & telecommunications\', \'samsung\', \'r&d\', \'srv\', \'hanoi university of science & technology\'], \'major\': [\'computer engineering\'], \'gpa\': [], \'name\': [\'nguyen tien dung\'], \'skill\': [\'windows os\', \'ejabberd\', \'docker\', \'c/c++\', \'ipv6\', \'pipeline\', \'os\', \'tizen\', \'python\', \'webrtc\', \'smack\', \'cicd\', \'agile\', \'ubuntu os\', \'windows\', \'linux\', \'testing\', \'java\', \'migrate\', \'ops\', \'ml\', \'machine learning\', \'embbeded\', \'flutter\', \'deploying and monitoring\', \'opearting\', \'identify observations events\', \'git\', \'systemd\', \'unix\', \'xmpp\', \'team working\', \'jira\', \'ios\', \'android\', \'dart\'], \'gender\': [\'male\'], \'job_title\': [\'software engineer\', \'developer\'], \'profile_url\': [\'mail.com\', \'www.terabit.com.au/\', \'www.ejabberd.im/\', \'topcv.vn\'], \'email\': [], \'phone\': [\'0973621049\'], \'education\': [], \'file_path\': \'/data/files/cv/page/Nguyen-Tien-Dung.pdf\'}, {\'_id\': ObjectId(\'66c6abfeea4dd50402925c93\'), \'organization\': [\'fschool\', \'hanoi university of science and technology\', \'ftech.ai\', \'the school of information and communications technology hanoi university\', \'sekisho sponsored japanese language scholarship\'], \'major\': [\'mathematics and informatics\'], \'gpa\': [], \'name\': [\'nguyen van nghiem\'], \'skill\': [\'seallms\', \'object oriented programming\', \'bm25\', \'llms\', \'problem solving\', \'oop\', \'large language\', \'/\', \'docker\', \'c/c++\', \'vllm\', \'python\', \'vinallama\', \'database\', \'llm\', \'math\', \'github\', \'tensorflow\', \'deep learning\', \'rtx\', \'vectordb\', \'rag\', \'chromadb\', \'jd\', \'mathematics\', \'machine learning\', \'pytorch\', \'cpa\', \'git\', \'gpt\', \'c#\', \'chatbot\', \'hackathon\', \'ftech.ai\', \'sql server\'], \'gender\': [\'male\'], \'job_title\': [\'teaching assistant\', \'nlp engineer\', \'ai engineer\'], \'profile_url\': [\'github.com/nguyenvannghiem0312/SAMI_Q\', \'github.com/nguyenvannghiem0312\', \'FQA.vn\', \'topcv.vn\', \'FTECH.AI\', \'github.com/nguyenvannghiem0312/AI_CHALLENGE\', \'github.com/nguyenvannghiem0312/Recommendation_system_for_recruitment\'], \'email\': [\'nguyenvannghiem0312@gmail.com\'], \'phone\': [\'0399802905\'], \'education\': [\'bachelor\'], \'file_path\': \'/data/files/cv/page/NguyenVanNghiem.pdf\'}, {\'_id\': ObjectId(\'66c6abfeea4dd50402925c95\'), \'organization\': [\'tu quang & dat pham & can\', \'phenikaa university\', \'univer ...
# Please provide the name or ID of your CV to locate its local storage path in the system.
# 11
# 11
# [{'_id': ObjectId('66c6abfeea4dd50402925c8d'), 'organization': ['ho chi minh university of science', 'soict hackathon', 'vietai hanoi vietnam', 'foundation of deep learning and advanced natural language processing', 'tymlez cohort', 'naver samsung tiki and vietcombank', 'apcs', 'ieee international conference on systems man and cybernetics', 'ieee international conference on software testing verification and validation', 'katalon inc.', 'slu spoken language understanding', 'department of science and technology', 'ho chi minh university of science vietnam', 'advantech group', 'hanoi university of science and technology', 'benit ltd. hanoi vietnam', 'department of information and communications vietnam national university', 'ho chi minh vietnam', 'fodl', 'aiot innoworks', 'department of education and training hcm', 'bkai & naver'], 'major': ['ai/software research intern', 'advanced program', 'information and communication technology', 'computer science'], 'gpa': ['gpa 3.85/4.00'], 'name': ['thanh duy cao'], 'skill': ['flask', 'next.js', 'research', 'api testing', 'cvpr workshop', 'typescript', 'asr', 'reactjs', 'vctube', 'ai challenge', 'artificial intelligence', 'nestjs'], 'gender': ['male'], 'job_title': ['teaching assistant', 'developer intern'], 'profile_url': [], 'email': ['ctduy20@apcs.fitus.edu.vn'], 'phone': ['84 708 624 730'], 'education': ['bachelor'], 'batch_id': ObjectId('66c6abf7ea4dd50402925c8c'), 'file_path': '/data/files/cv/page/CaoThanhDuy_Resume.pdf', 'image_paths': ['/data/files/cv/image/CaoThanhDuy_Resume-0-1.png', '/data/files/cv/image/CaoThanhDuy_Resume-0-2.png', '/data/files/cv/image/CaoThanhDuy_Resume-1-1.png'], 'score': 1}, {'_id': ObjectId('66c6abfeea4dd50402925c8e'), 'organization': ['safehorizons', 'vietnam korea university of information and communication technology'], 'major': [], 'gpa': ['gpa 3.65'], 'name': ['nguyen thi chau thi'], 'skill': ['assisting students', 'java', 'mysql', 'css', 'firebase', 'inventory tracking', 'debugging', 'php', 'flutter', 'c++', 'restful', 'spring', 'html'], 'gender': ['female'], 'job_title': ['teaching assistant', 'software engineer', 'internship'], 'profile_url': [], 'email': ['chauthi1704@gmail.com'], 'phone': ['84387285692'], 'education': [], 'batch_id': ObjectId('66c6abf7ea4dd50402925c8c'), 'file_path': '/data/files/cv/page/ChauThi_resume.pdf', 'image_paths': [], 'score': 1}, {'_id': ObjectId('66c6abfeea4dd50402925c8f'), 'organization': ['tas design group', 'vng kms', 'dut danang vietnam', 'danang university of science and technology', 'youth union', 'university of science and technology organizational & volunteer'], 'major': [], 'gpa': ['gpa 3.89'], 'name': [], 'skill': ['raspberry pi', 'data analysis', 'eda', 'regression', 'teamwork', 'seaborn', 'c++', 'numpy', 'data processing', 'scikit', 'python', 'verbal communication', 'presentation', 'data visualization', 'ai model', 'matplotlib', 'communication', 'data driven', 'managing and administering the activities', 'forecasting', 'ml', 'machine learning', 'pytorch', 'english', 'artificial intelligence', 'scikit learn', 'data structures', 'neural networks', 'time series', 'data science', 'pandas', 'processing data', 'programming languages', 'dl', 'forecasting time series'], 'gender': [], 'job_title': ['deputy secretary'], 'profile_url': ['linkedin.com/in/quoc'], 'email': ['hoquocthienanh@gmail.com'], 'phone': ['0905500293'], 'education': ['bachelor'], 'batch_id': ObjectId('66c6abf7ea4dd50402925c8c'), 'file_path': '/data/files/cv/page/HoQuocThienAnh.pdf', 'image_paths': [], 'score': 1}, {'_id': ObjectId('66c6abfeea4dd50402925c90'), 'organization': ['github', 'nals joint stock company', 'vietnam bank for agriculture and rural development', 'hai chau da nang', 'da nang', 'vietnam korea university of ict', 'vietnam korea university of information and communication technology', 'vku excellent student', 'aglie', 'vku corporate scholarship'], 'major': ['computer science'], 'gpa': ['gpa 3.65'], 'name': ['huynh thi phuoc'], 's ...
# {'GPA': 3.0, 'major': 'Computer Science', 'skills': ['Python', 'Java', 'Data Science'], 'gender': 'male', 'job_title': ['Software Engineer', 'Data Analyst']}
# 8
# 3
# python
# java
# data science
# python
# software engineer
# [{'_id': ObjectId('66c6abfeea4dd50402925c8d'), 'organization': ['ho chi minh university of science', 'soict hackathon', 'vietai hanoi vietnam', 'foundation of deep learning and advanced natural language processing', 'tymlez cohort', 'naver samsung tiki and vietcombank', 'apcs', 'ieee international conference on systems man and cybernetics', 'ieee international conference on software testing verification and validation', 'katalon inc.', 'slu spoken language understanding', 'department of science and technology', 'ho chi minh university of science vietnam', 'advantech group', 'hanoi university of science and technology', 'benit ltd. hanoi vietnam', 'department of information and communications vietnam national university', 'ho chi minh vietnam', 'fodl', 'aiot innoworks', 'department of education and training hcm', 'bkai & naver'], 'major': ['ai/software research intern', 'advanced program', 'information and communication technology', 'computer science'], 'gpa': ['gpa 3.85/4.00'], 'name': ['thanh duy cao'], 'skill': ['flask', 'next.js', 'research', 'api testing', 'cvpr workshop', 'typescript', 'asr', 'reactjs', 'vctube', 'ai challenge', 'artificial intelligence', 'nestjs'], 'gender': ['male'], 'job_title': ['teaching assistant', 'developer intern'], 'profile_url': [], 'email': ['ctduy20@apcs.fitus.edu.vn'], 'phone': ['84 708 624 730'], 'education': ['bachelor'], 'batch_id': ObjectId('66c6abf7ea4dd50402925c8c'), 'file_path': '/data/files/cv/page/CaoThanhDuy_Resume.pdf', 'image_paths': ['/data/files/cv/image/CaoThanhDuy_Resume-0-1.png', '/data/files/cv/image/CaoThanhDuy_Resume-0-2.png', '/data/files/cv/image/CaoThanhDuy_Resume-1-1.png'], 'score': 0}, {'_id': ObjectId('66c6abfeea4dd50402925c91'), 'organization': ['pixta vietnam company', 'ha noi teacher', 'ha noi university of science and technology', 'ha noi research assistant', 'ha noi labeling data', 'hanoi university of science and technology', 'hust semester', 'bkai international research center', 'school of information and communication technology'], 'major': ['computer science'], 'gpa': ['3.72/4 achievements'], 'name': ['nguyen hoang phuc'], 'skill': ['imdb', 'data analytics', 'css', 'c++', 'mongodb', 'python', 'image classification', 'mysql', 'c', 'pycharm', 'project management', 'tensorflow', 'java', 'rag', 'deverloper', 'pytorch', 'intellij', 'cpa', 'html', 'visual studio code', 'idea', 'data science', 'chatbot', 'javascript', 'object oriented', 'cloud/databases'], 'gender': ['male'], 'job_title': ['teacher assistant', 'ai engineer'], 'profile_url': [], 'email': ['phuc.nh215452@sis.hust.edu.vn'], 'phone': ['84 975594053'], 'education': [], 'batch_id': ObjectId('66c6abf7ea4dd50402925c8c'), 'file_path': '/data/files/cv/page/Nguyễn_Hoàng_Phúc_CVt.pdf', 'image_paths': [], 'score': 0.6}, {'_id': ObjectId('66c6abfeea4dd50402925c97'), 'organization': ['bkprice system university hanoi vn my graduation', 'blockchain labs', 'b4e bkc labs', 'oraichain labs hanoi vn', 'tiki recommendation', 'hanoi university of science and technology hanoi vn', 'data center'], 'major': ['computer science'], 'gpa': ['3.65 sep.'], 'name': ['le thanh long'], 'skill': ['quadtree', 'chart patterns', 'visualization', 'defilens', 'pdf', 'google', 'oop', 'redis', 'charts', 'c++', 'chart', 'optimizing search', 'caching', 'pdf generatation', 'mongodb', 'nosql', 'python', 'merkle', 'elastic search', 'qr', 'kafka', 'realtime processing', 'system design', 'data structure & algorithm', 'blockchain', 'cache', 'deep learning', 'databases', 'hashes', 'elasticsearch', 'cpa', 'reducing latency', 'debezium', 'js', 'klinechart', 'postgresql', 'optimize system', 'analysis', 'kafka queues', 'optical character recognition', 'gc s3', 'cloud storage', 'airflow', 'data', 'ocr', 'amazon s3', 'nestjs', 'sql'], 'gender': ['male'], 'job_title': ['ai and software engineer', 'software engineer'], 'profile_url': [], 'email': ['attentionocr@gmail.com'], 'phone': ['84 969973012'], 'education': ['bachelor'], 'batch_id': ObjectId('66c6abf ...
# [{'role': 'system', 'content': "You are a helpful assistant. When users ask about CV information, write it down in a summary way. Use below information to answer the question from user. \n Information: [{'_id': ObjectId('66c6abfeea4dd50402925c91'), 'organization': ['pixta vietnam company', 'ha noi teacher', 'ha noi university of science and technology', 'ha noi research assistant', 'ha noi labeling data', 'hanoi university of science and technology', 'hust semester', 'bkai international research center', 'school of information and communication technology'], 'major': ['computer science'], 'gpa': ['3.72/4 achievements'], 'name': ['nguyen hoang phuc'], 'skill': ['imdb', 'data analytics', 'css', 'c++', 'mongodb', 'python', 'image classification', 'mysql', 'c', 'pycharm', 'project management', 'tensorflow', 'java', 'rag', 'deverloper', 'pytorch', 'intellij', 'cpa', 'html', 'visual studio code', 'idea', 'data science', 'chatbot', 'javascript', 'object oriented', 'cloud/databases'], 'gender': ['male'], 'job_title': ['teacher assistant', 'ai engineer'], 'profile_url': [], 'email': ['phuc.nh215452@sis.hust.edu.vn'], 'phone': ['84 975594053'], 'education': [], 'file_path': '/data/files/cv/page/Nguyễn_Hoàng_Phúc_CVt.pdf'}, {'_id': ObjectId('66c6abfeea4dd50402925c97'), 'organization': ['bkprice system university hanoi vn my graduation', 'blockchain labs', 'b4e bkc labs', 'oraichain labs hanoi vn', 'tiki recommendation', 'hanoi university of science and technology hanoi vn', 'data center'], 'major': ['computer science'], 'gpa': ['3.65 sep.'], 'name': ['le thanh long'], 'skill': ['quadtree', 'chart patterns', 'visualization', 'defilens', 'pdf', 'google', 'oop', 'redis', 'charts', 'c++', 'chart', 'optimizing search', 'caching', 'pdf generatation', 'mongodb', 'nosql', 'python', 'merkle', 'elastic search', 'qr', 'kafka', 'realtime processing', 'system design', 'data structure & algorithm', 'blockchain', 'cache', 'deep learning', 'databases', 'hashes', 'elasticsearch', 'cpa', 'reducing latency', 'debezium', 'js', 'klinechart', 'postgresql', 'optimize system', 'analysis', 'kafka queues', 'optical character recognition', 'gc s3', 'cloud storage', 'airflow', 'data', 'ocr', 'amazon s3', 'nestjs', 'sql'], 'gender': ['male'], 'job_title': ['ai and software engineer', 'software engineer'], 'profile_url': [], 'email': ['attentionocr@gmail.com'], 'phone': ['84 969973012'], 'education': ['bachelor'], 'file_path': '/data/files/cv/page/Software_Engineer_Resume.pdf'}]"}, {'role': 'user', 'content': 'Give me some resume example in your system'}]
# {'skills': ['machine learning', 'deep learning']}
# 11
# 11
# machine learning
# machine learning
# machine learning
# deep learning
# machine learning
# deep learning
# machine learning
# deep learning
# deep learning
# ...
# Traceback (most recent call last):
#   File "/home/long/anaconda3/envs/mlops-env/lib/python3.10/site-packages/gradio/chat_interface.py", line 592, in _stream_fn
#     first_response = await async_iteration(generator)
#   File "/home/long/anaconda3/envs/mlops-env/lib/python3.10/site-packages/gradio/utils.py", line 657, in async_iteration
#     return await iterator.__anext__()
#   File "/home/long/anaconda3/envs/mlops-env/lib/python3.10/site-packages/gradio/utils.py", line 650, in __anext__
#     return await anyio.to_thread.run_sync(
#   File "/home/long/anaconda3/envs/mlops-env/lib/python3.10/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/long/anaconda3/envs/mlops-env/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2177, in run_sync_in_worker_thread
#     return await future
#   File "/home/long/anaconda3/envs/mlops-env/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 859, in run
#     result = context.run(func, *args)
#   File "/home/long/anaconda3/envs/mlops-env/lib/python3.10/site-packages/gradio/utils.py", line 636, in run_sync_iterator_async
#     raise StopAsyncIteration() from None
# StopAsyncIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/long/anaconda3/envs/mlops-env/lib/python3.10/site-packages/gradio/queueing.py", line 541, in process_events
#     response = await route_utils.call_process_api(
#   File "/home/long/anaconda3/envs/mlops-env/lib/python3.10/site-packages/gradio/route_utils.py", line 276, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/long/anaconda3/envs/mlops-env/lib/python3.10/site-packages/gradio/blocks.py", line 1928, in process_api
#     result = await self.call_function(
#   File "/home/long/anaconda3/envs/mlops-env/lib/python3.10/site-packages/gradio/blocks.py", line 1526, in call_function
#     prediction = await utils.async_iteration(iterator)
#   File "/home/long/anaconda3/envs/mlops-env/lib/python3.10/site-packages/gradio/utils.py", line 657, in async_iteration
#     return await iterator.__anext__()
#   File "/home/long/anaconda3/envs/mlops-env/lib/python3.10/site-packages/gradio/utils.py", line 783, in asyncgen_wrapper
#     response = await iterator.__anext__()
# RuntimeError: async generator raised StopAsyncIteration
# {'gender': 'female', 'skills': ['software engineering', 'web', 'app']}
# 3
# 3
# web
# [{'_id': ObjectId('66c6b46eea4dd50402925c9b'), 'organization': ['safehorizons', 'vietnam korea university of information and communication technology'], 'major': [], 'gpa': ['gpa 3.65'], 'name': ['nguyen thi chau thi'], 'skill': ['assisting students', 'java', 'mysql', 'css', 'firebase', 'inventory tracking', 'debugging', 'php', 'flutter', 'c++', 'restful', 'spring', 'html'], 'gender': ['female'], 'job_title': ['teaching assistant', 'software engineer', 'internship'], 'profile_url': [], 'email': ['chauthi1704@gmail.com'], 'phone': ['84387285692'], 'education': [], 'batch_id': ObjectId('66c6b464ea4dd50402925c98'), 'file_path': '/data/files/cv/page/ChauThi_resume.pdf', 'image_paths': [], 'score': 0}, {'_id': ObjectId('66c6b46eea4dd50402925c9d'), 'organization': ['github', 'nals joint stock company', 'vietnam bank for agriculture and rural development', 'hai chau da nang', 'da nang', 'vietnam korea university of ict', 'vietnam korea university of information and communication technology', 'vku excellent student', 'aglie', 'vku corporate scholarship'], 'major': ['computer science'], 'gpa': ['gpa 3.65'], 'name': ['huynh thi phuoc'], 'skill': ['kotlin', 'handle course', 'docker', 'developing innovative solutions', 'mysql', 'robocar competition', 'guiding and correcting', 'project management', 'quickly grasping', 'laravel', 'java', 'html/css', 'vs code', 'intellij', 'php', 'spring', 'software development', 'english', 'git', 'consolation prize', 'dart', 'sql'], 'gender': ['female'], 'job_title': ['teaching assistant', 'software engineer', 'intern'], 'profile_url': ['github.com/huynhthiphuoc11/studentManagement', 'github.com/huynhthiphuoc11', 'github.com/huynhthiphuoc11/hopital_system'], 'email': ['huynhthiphuoc04@gmail.com'], 'phone': ['0355 176 782'], 'education': ['bachelor'], 'batch_id': ObjectId('66c6b464ea4dd50402925c98'), 'file_path': '/data/files/cv/page/huynhthiphuoc_resume1.pdf', 'image_paths': [], 'score': 0}, {'_id': ObjectId('66c6b46eea4dd50402925ca8'), 'organization': ['vku university', 'vietnam korea university of information and communication technology'], 'major': ['information technology engineering'], 'gpa': ['gpa 3.79/4.0'], 'name': ['nguyen huyen trang'], 'skill': ['react', 'english learning', 'teamwork', 'error handling', 'css', 'bootstrap', 'problem solving', 'crud', 'c++', 'docker', 'jwttoken', 'python', 'presentation', 'mysql', 'design adaptability', 'github', 'boot', 'git&github', 'communication', 'java', 'web technology', 'system analysis and design', 'spring', 'reactjs', 'restful', 'vocabulary learning', 'designing and developing web applications', 'english', 'html', 'chatgpt', 'java spring', 'analytical', 'data structures and algorithms', 'javascript', 'object oriented', 'tailwindcss', 'dart', 'jquery', 'sql'], 'gender': ['female'], 'job_title': ['backend engineer'], 'profile_url': ['linkedin.com/in/trang', 'github.com/HuyenTrang0506/VoteSystem', 'github.com/HuyenTrang0506', 'github.com/Duycan17/Vocatel'], 'email': ['tranghuyen9696@gmail.com'], 'phone': [], 'education': ['bachelor'], 'batch_id': ObjectId('66c6b464ea4dd50402925c98'), 'file_path': '/data/files/cv/page/TrangNguyenHuyen_Resume_Intern.pdf', 'image_paths': [], 'score': 0.3333333333333333}]
# {'GPA': 3.2, 'gender': 'male', 'skills': ['AI', 'Machine Learning', 'Data Science']}
# 11
# 5
# ai
# ai
# data science
# machine learning
# data science
# ai
# [{'_id': ObjectId('66c6b46eea4dd50402925c99'), 'organization': ['vku it club', 'korea university of information', 'sigconn tap a web', 'safehorizons software service company'], 'major': [], 'gpa': ['gpa 9/10', 'gpa 3.58/4'], 'name': ['bao nhan ho sy'], 'skill': ['nfc card', 'django', 'temperature sensors', 'microservices', 'teamwork', 'parse', 'dbms', 'react native', 'web design', 'crud', 'nfc', 'os', 'mongodb', 'back end', 'nextjs server', 'python', 'presentation', 'mysql', 'leadership', 'flask', 'github', 'git&github', 'linux', 'redux', 'java', 'communication', 'research', 'agile scrum', 'restful api', 'reactjs', 'english', 'nextjs', 'creating and managing', 'zustand', 'postgresql', 'sqlite', 'git', 'esp32', 'object oriented', 'tailwindcss'], 'gender': ['male'], 'job_title': ['fullstack developer', 'speaker'], 'profile_url': ['github.com/bobaonhan123/sigconn', 'bwd2023remake.vercel.app/', 'linkedin.com/in/bao', 'github.com/phuquocchamp/bwd2023remake', 'github.com/phuquocchamp/signconn'], 'email': ['hosybaonhan2004@gmail.com'], 'phone': ['0845 562 771'], 'education': [], 'batch_id': ObjectId('66c6b464ea4dd50402925c98'), 'file_path': '/data/files/cv/page/bao nhan ho sy-cv.pdf', 'image_paths': [], 'score': 0}, {'_id': ObjectId('66c6b46eea4dd50402925c9a'), 'organization': ['ho chi minh university of science', 'soict hackathon', 'vietai hanoi vietnam', 'foundation of deep learning and advanced natural language processing', 'tymlez cohort', 'naver samsung tiki and vietcombank', 'apcs', 'ieee international conference on systems man and cybernetics', 'ieee international conference on software testing verification and validation', 'katalon inc.', 'slu spoken language understanding', 'department of science and technology', 'ho chi minh university of science vietnam', 'advantech group', 'hanoi university of science and technology', 'benit ltd. hanoi vietnam', 'department of information and communications vietnam national university', 'ho chi minh vietnam', 'fodl', 'aiot innoworks', 'department of education and training hcm', 'bkai & naver'], 'major': ['ai/software research intern', 'advanced program', 'information and communication technology', 'computer science'], 'gpa': ['gpa 3.85/4.00'], 'name': ['thanh duy cao'], 'skill': ['flask', 'next.js', 'research', 'api testing', 'cvpr workshop', 'typescript', 'asr', 'reactjs', 'vctube', 'ai challenge', 'artificial intelligence', 'nestjs'], 'gender': ['male'], 'job_title': ['teaching assistant', 'developer intern'], 'profile_url': [], 'email': ['ctduy20@apcs.fitus.edu.vn'], 'phone': ['84 708 624 730'], 'education': ['bachelor'], 'batch_id': ObjectId('66c6b464ea4dd50402925c98'), 'file_path': '/data/files/cv/page/CaoThanhDuy_Resume.pdf', 'image_paths': ['/data/files/cv/image/CaoThanhDuy_Resume-0-1.png', '/data/files/cv/image/CaoThanhDuy_Resume-0-2.png', '/data/files/cv/image/CaoThanhDuy_Resume-1-1.png'], 'score': 0.3333333333333333}, {'_id': ObjectId('66c6b46eea4dd50402925c9e'), 'organization': ['pixta vietnam company', 'ha noi teacher', 'ha noi university of science and technology', 'ha noi research assistant', 'ha noi labeling data', 'hanoi university of science and technology', 'hust semester', 'bkai international research center', 'school of information and communication technology'], 'major': ['computer science'], 'gpa': ['3.72/4 achievements'], 'name': ['nguyen hoang phuc'], 'skill': ['imdb', 'data analytics', 'css', 'c++', 'mongodb', 'python', 'image classification', 'mysql', 'c', 'pycharm', 'project management', 'tensorflow', 'java', 'rag', 'deverloper', 'pytorch', 'intellij', 'cpa', 'html', 'visual studio code', 'idea', 'data science', 'chatbot', 'javascript', 'object oriented', 'cloud/databases'], 'gender': ['male'], 'job_title': ['teacher assistant', 'ai engineer'], 'profile_url': [], 'email': ['phuc.nh215452@sis.hust.edu.vn'], 'phone': ['84 975594053'], 'education': [], 'batch_id': ObjectId('66c6b464ea4dd50402925c98'), 'file_path': '/data/files/cv/page/Nguyễn_Hoàng_Phúc_CVt.pdf', 'i ...
# [{'role': 'system', 'content': 'You are a helpful assistant. When users ask about CV information, write it down in a summary way. Use below information to answer the question from user. \n Information: [{\'_id\': ObjectId(\'66c6b46eea4dd50402925c9a\'), \'organization\': [\'ho chi minh university of science\', \'soict hackathon\', \'vietai hanoi vietnam\', \'foundation of deep learning and advanced natural language processing\', \'tymlez cohort\', \'naver samsung tiki and vietcombank\', \'apcs\', \'ieee international conference on systems man and cybernetics\', \'ieee international conference on software testing verification and validation\', \'katalon inc.\', \'slu spoken language understanding\', \'department of science and technology\', \'ho chi minh university of science vietnam\', \'advantech group\', \'hanoi university of science and technology\', \'benit ltd. hanoi vietnam\', \'department of information and communications vietnam national university\', \'ho chi minh vietnam\', \'fodl\', \'aiot innoworks\', \'department of education and training hcm\', \'bkai & naver\'], \'major\': [\'ai/software research intern\', \'advanced program\', \'information and communication technology\', \'computer science\'], \'gpa\': [\'gpa 3.85/4.00\'], \'name\': [\'thanh duy cao\'], \'skill\': [\'flask\', \'next.js\', \'research\', \'api testing\', \'cvpr workshop\', \'typescript\', \'asr\', \'reactjs\', \'vctube\', \'ai challenge\', \'artificial intelligence\', \'nestjs\'], \'gender\': [\'male\'], \'job_title\': [\'teaching assistant\', \'developer intern\'], \'profile_url\': [], \'email\': [\'ctduy20@apcs.fitus.edu.vn\'], \'phone\': [\'84 708 624 730\'], \'education\': [\'bachelor\'], \'file_path\': \'/data/files/cv/page/CaoThanhDuy_Resume.pdf\'}, {\'_id\': ObjectId(\'66c6b46eea4dd50402925c9e\'), \'organization\': [\'pixta vietnam company\', \'ha noi teacher\', \'ha noi university of science and technology\', \'ha noi research assistant\', \'ha noi labeling data\', \'hanoi university of science and technology\', \'hust semester\', \'bkai international research center\', \'school of information and communication technology\'], \'major\': [\'computer science\'], \'gpa\': [\'3.72/4 achievements\'], \'name\': [\'nguyen hoang phuc\'], \'skill\': [\'imdb\', \'data analytics\', \'css\', \'c++\', \'mongodb\', \'python\', \'image classification\', \'mysql\', \'c\', \'pycharm\', \'project management\', \'tensorflow\', \'java\', \'rag\', \'deverloper\', \'pytorch\', \'intellij\', \'cpa\', \'html\', \'visual studio code\', \'idea\', \'data science\', \'chatbot\', \'javascript\', \'object oriented\', \'cloud/databases\'], \'gender\': [\'male\'], \'job_title\': [\'teacher assistant\', \'ai engineer\'], \'profile_url\': [], \'email\': [\'phuc.nh215452@sis.hust.edu.vn\'], \'phone\': [\'84 975594053\'], \'education\': [], \'file_path\': \'/data/files/cv/page/Nguyễn_Hoàng_Phúc_CVt.pdf\'}, {\'_id\': ObjectId(\'66c6b46eea4dd50402925ca3\'), \'organization\': [\'da nang university of technology and education\', \'tas design group\', "bachelor\'s degree", \'vietnam uk institute for research and training 2 of 2 vietcv.io\', \'microsoft\', \'synthesis\'], \'major\': [], \'gpa\': [\'gpa 3.78\'], \'name\': [\'phan minh nhat\'], \'skill\': [\'data analysis\', \'teamwork\', \'seaborn\', \'forecasting time series\', \'c/c++\', \'mammography\', \'data processing\', \'python\', \'verbal communication\', \'presentation\', \'image recognition\', \'r\', \'data visualization\', \'accelerate computation\', \'matplotlib\', \'mlp\', \'deep learning\', \'predict power demand\', \'data visualation\', \'communication\', \'java\', \'convnext\', \'machine learning\', \'data structures\', \'neural networks\', \'arti cial intelligence\', \'programming\', \'regression/classi\', \'breast cancer\', \'c#\', \'data science\', \'macroscopic images\', \'whisper\', \'matlab\', \'transformer\'], \'gender\': [\'male\'], \'job_title\': [], \'profile_url\': [\'github.com/PhanNhat0209\', \'VietCV ...
